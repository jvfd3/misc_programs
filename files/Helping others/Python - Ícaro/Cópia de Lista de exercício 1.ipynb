# %% [markdown]
# <?xml version="1.0" encoding="UTF-8"?>
# <html>
#   <body>
#     <header></header>
#         <CENTER>
#           <img src="https://www.uvv.br/wp-content/themes/uvvBr/templates/assets//img/logouvv.svg" alt="UVV-LOGO" style = width="100px"; height="100px">
#         </CENTER>
#         <CENTER><b>Laboratório de Programação- PYTHON</b><br/>
#         <CENTER><b>Lista de Exercício 1</b><br/>
#         <CENTER><b>Professor Alessandro Bertolani Oliveira</b></CENTER><br/>

# %% [markdown]
# # NOMES DO GRUPO:

# %% [markdown]
# ## Nome 1: Ícaro Leite Ramos

# %% [markdown]
# ## Nome 2: Thiago Aguiar Sant'Ana Segal

# %% [markdown]
# ## Nome 3:

# %% [markdown]
# ## Exercício 1A: OK
# Calcular e exibir a hipotenusa (𝐴) de um triângulo retângulo de catetos 𝐵 e 𝐶, sabendo que:
#
# ![1A.png](data:image/png;base64,...)

# %%
"""
Seus Comentários:
"""
import math
print('Vamos calcular a hipotenusa!')
B = int(input('Insira o valor do cateto B: '))
C = int(input('Insira o valor do cateto C:  '))
A = pow((pow(B,2)+pow(C,2)),1/2)
print(f'Valor da hipotenusa eh: {A}')
# Out:
# Vamos calcular a hipotenusa!
# Insira o valor do cateto B: 3
# Insira o valor do cateto C:  4
# Valor da hipotenusa eh: 5.0

# %% [markdown]
# ```
# # Isto está formatado como código
# ```
#
# ## Exercício 1B: OK
# Calcular e exibir a área de um quadrado de lado (L):
#
# ![1B.jpg](data:image/jpeg;base64,...)

# %%
import math
lado = int(input('Insere a area ai maluco: '))
area = math.pow(lado, 2)
print(area)

# %% [markdown]
# ## Exercício 1C: OK
# Calcular e exibir a área de um retângulo de lado (L) e altura (H). Área = L * H.

# %%
print('Vamos calcular a área de um retângulo!')
L = int(input('Insira o valor do lado: '))
H = int(input('Insira o valor da altura:  '))
Area = L * H
print(f'Valor da area eh: {Area}')
# Out:
# Vamos calcular a área de um retângulo!
# Insira o valor do lado: 2
# Insira o valor da altura:  5
# Valor da area eh: 10

# %% [markdown]
# ## Exercício 1D: OK
# Calcular e exibir a área e o comprimento de um círculo de Raio (R), sabendo que,
# Área = π * R2
# e
# Comprimento = 2 * π * R.

# %%
import math
pi = float(math.pi)
raio = float(input('Qual e o raio da boca de fumo: '))
area = pi * math.pow(raio, 2)
comprimento = 2 * pi * raio
print(f'A área é {area: .2f} e o comprimento é {comprimento: .2f}')

# %% [markdown]
# ## Exercício 1E: OK
# Calcular e exibir o IMC (Índice de Massa Corpórea) de uma pessoa de altura (H) em metros e massa
# (M) em quilogramas, sabendo que IMC = M / H2
# .

# %%
print('Vamos descobrir seu IMC!')
H = float(input('Insira sua altura em metros: '))
M = float(input('Insira sua massa em quilogramas: '))
IMC = M / H ** 2
print(f'Seu IMC é de: {IMC}')
# Out:
# Vamos descobrir seu IMC!
# Insira sua altura em metros: 1.85
# Insira sua massa em quilogramas: 72
# Seu IMC é de: 21.0372534696859

# %% [markdown]
# ## Exercício 1F: OK
# Calcular e exibir o volume em litros de uma esfera de Raio (R), sabendo que o usuário deve informar
# o Raio (R) em metros. Sabe-se que: 𝑉𝑜𝑙𝑢𝑚𝑒𝐸𝑠𝑓𝑒𝑟𝑎 = 4
# 3
# ⁄ * π * R3
# e que 1 Litro é igual a 10-3 m3
# .

# %%
import math

pi = math.pi
raio = float(input('Qual é o raio da esfera?: '))
volume_esf = 4/3*pi*math.pow(raio, 3)
print(f'O volume da esfera é {volume_esf: .2f}')

# %% [markdown]
# ## Exercício 1G: OK
# Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no
# mês. Calcule e mostre o total do seu salário no referido mês, sabendo-se que são descontados 11%
# para o Imposto de Renda, 8% para o INSS e 5% para o sindicato. Com isso, exiba na tela:
#
# ✓ salário bruto.
#
# ✓ quanto pagou ao INSS.
#
# ✓ quanto pagou ao sindicato.
#
# ✓ o salário líquido = Brutos - Descontos

# %%
SH = float(input('Insira quanto voce ganha por hora: '))
HM = int(input('Insira quantas horas voce trabalha por mes: '))
SB = SH * HM
print(f'Seu salario bruto é de: {SB}')
IR = SB * 0.11
print(f'Voce pagou R${IR} de Imposto de Renda')
INSS = SB * 0.08
print(f'Voce pagou R${INSS} de INSS')
Sind = SB * 0.05
print(f'Voce pagou R${Sind} ao Sindicato')
Desc = IR + INSS + Sind
SL = SB - Desc
print(f'Seu Salario Liquido foi de R${SL}')
# Out:
# Insira quanto voce ganha por hora: 10
# Insira quantas horas voce trabalha por mes: 100
# Seu salario bruto é de: 1000.0
# Voce pagou R$110.0 de Imposto de Renda
# Voce pagou R$80.0 de INSS
# Voce pagou R$50.0 ao Sindicato
# Seu Salario Liquido foi de R$760.0

# %% [markdown]
# ## Exercício 1H:OK
# Calcular e exibir a quantidade de tinta (em latas) e o custo (em reais) para pintar um tanque cilíndrico
# de base circular de Raio (R) e altura (H) em metros, sabendo que:
#
# ✓ 1 lata = 5 litros.
#
# ✓ 1 litro pinta 3 metros quadrados.
#
# ✓ 1 lata custa 50 Reais.

# %%
import math

pi = math.pi
raio = float(input('Qual é o raio da esfera?: '))
volume_esf = 4/3*pi*math.pow(raio, 3)


litro = 1
lata = litro*5
precolata = 50.00

totaltinta = volume_esf *lata
totalpreco = totaltinta * precolata

print(f'O volume da esfera é {volume_esf: .2f}')
print(f'A quantidade de tinta necessária é {totaltinta} litros de tinta')
print(f'O total a pagar é: R$ {totalpreco: .2f}')

# %% [markdown]
# ## Exercício 1I: OK
# Calcular e exibir a distância entre dois pontos quaisquer do plano, P(x1, y1) e Q(x2, y2), sabendo que
# a fórmula da distância é d = √(x2 – x1)
# 2 + (y2 – y1)
# 2, sendo os pontos P(x1, y1) e Q(x2, y2) como
# dados de entrada.
#
# ![image.png](data:image/png;base64,...)

# %%
import math
X1 = float(input('Digite o valor de X do primeiro Ponto: '))
Y1 = float(input('Digite o valor de Y do segundo Ponto: '))

X2 = float(input('Digite o valor de X do primeiro Ponto: '))
Y2 = float(input('Digite o valor de Y do segundo Ponto: '))

Dist = (((X2-X1)**2)+((Y2-Y1)*2))**0.5

print(f'A distancia entre os pontos é {Dist}')
# Out:
# Digite o valor de X do primeiro Ponto: 3
# Digite o valor de Y do segundo Ponto: 3
# Digite o valor de X do primeiro Ponto: 4
# Digite o valor de Y do segundo Ponto: 4
# A distancia entre os pontos é 1.7320508075688772

# %% [markdown]
# ## Exercício 1J:OK
# Calcular e exibir o tempo (em horas) de autonomia de uma caixa d’água de um restaurante que
# consome 1350 litros por hora em média. O tanque do restaurante é cilíndrico de base circular de Raio
# (R) e de altura (H) em metros. Sabendo que 1 m3 = 1000 Litros.

# %%
import math
import datetime
pi = math.pi
raio = float(input('Qual é o raio da esfera?: '))
metro_cub = math.pow(raio, 3)

volume_esf = (4 / 3 * pi * metro_cub)
volume = metro_cub *1000

# gasta = 1350/3600 -> 1350 Litros divididos em 3600 segundos = 1 hora

# AE TO COM DUVIDA
segundos = volume * 1350/3600


dias = segundos // 86400
segundos_rest = segundos % 86400
horas = segundos_rest // 3600
segundos_rest = segundos_rest % 3600
minutos = segundos_rest // 60
# segundos_rest = segundos_rest % 60
print(f'Essa caixa é autônoma por {dias} dias, {horas} horas e {minutos} minutos')

# %% [markdown]
# ## Exercício 1K: OK
# Faça um programa que peça o tamanho de um arquivo para download (em Megabytes) e a
# velocidade de um link de Internet (em Megabytes / Segundo), calcule e informe o tempo: Minutos +
# Segundos aproximado de download do arquivo usando este link.

# %%
AD = float(input('Insira o tamanho do download em mb: '))
VI = float(input('Insira a velocidade da sua internet e mb/s: '))
TT = AD / VI
M = TT // 60
S = TT % 60
print(f'Tempo de download sera de {M} minutos e {S} segundos')
# Out:
# Insira o tamanho do download em mb: 1200
# Insira a velocidade da sua internet e mb/s: 100
# Tempo de download sera de 0.0 minutos e 12.0 segundos

# %% [markdown]
# ## Exercício 1L: OK
# Calcular e exibir a distância máxima (em Quilômetros) de autonomia de um carro que possui um
# tanque de combustível cúbico de lado (L) em metros e Altura (h) de preenchimento do tanque.
# Sabendo que seu consumo é em média 10 km/litro. Sabendo que 1 m3 = 1000 Litros.

# %%
L=float(input('Insira o lado em m: '))
Dmax=(L**3)*10000
print(f'Distancias possiveis: {Dmax}')
# Out:
# Insira o lado em m: 2
# Distancias possiveis: 80000.0

# %% [markdown]
# ## EXERCÍCIOS: Estrutura de seleção: Simples, Composta e Encadeada.
# ## Exercício 1: OK
# Escrever um algoritmo em Python que determine o volume e a área de uma esfera de raio 𝑟 (∈ ℝ+
# ∗
# ).
# Sendo que 𝜋 = 3.14.
#
# ![image.png](data:image/png;base64,...)

# %%
import math
pi = math.pi

raio = int(input('Insira o raio: '))
if raio <= 0 :
    print('Valor de raio inválido: raio 𝑟 (∈ ℝ+ ∗)')
else:
    area = 4 * pi * math.pow(raio, 2)
    volume = 4 / 3 * pi * math.pow(raio, 3)
    print(f'\n Área = {area: .2f}\n Volume = {volume: .2f}')

# %% [markdown]
# ## Exercício 2: OK
# Escrever um algoritmo em Python que leia a Base (𝐵 > 0) e a Altura (𝐻 > 0) de um retângulo em
# centímetros e calcule e exiba na tela seu 𝑃𝑒𝑟í𝑚𝑒𝑡𝑟𝑜 (soma dos lados) em:
#
# ![image.png](data:image/png;base64,...)

# %%
B = 0
H = 0
while not(B > 0): 
  B = float(input('Insira o valor da Base: '))
  if (B <= 0):
    print('Valor errado, insira novamente')
while not(H>0):
  H = float(input('Insira o valor da Altura: '))
  if (H <= 0):
    print('Valor errado, insira novamente')
  
Pe = 2*(B+H)
print(f'O perímetro em Centímetros eh: {Pe}')
Po = Pe / 2.54
print(f'O perímetro em Polegadas eh: {Po: .2f}')
Ja = Po * 0.03
print(f'O perímetro em Jardas eh: {Ja: .2f}')
# Out:
# Insira o valor da Base: 2
# Insira o valor da Altura: 2
# O perímetro em Centímetros eh: 8.0
# O perímetro em Polegadas eh:  3.15
# O perímetro em Jardas eh:  0.09

# %% [markdown]
# ## Exercício 3: OK
# Faça um algoritmo em Python que leia o tempo (segundos) de permanência de um aluno no
# Laboratório de Programação: UVV e exiba na tela seu tempo de permanência: Horas + Minutos + Segundos. Exemplo: Tempo: 10000 Segundos = 2 Hora(s) + 46 Minuto(s) + 40 Segundo(s).

# %%
segundos = int(input("O tempo (em segundos) em que o aluno ficou no laboratório: "))

segundos_rest = segundos % 86400
horas = segundos_rest // 3600
segundos_rest = segundos_rest % 3600
minutos = segundos_rest // 60
segundos_rest = segundos_rest % 60

print("O aluno permaneceu no laboratório por", horas,"horas,",minutos,"minutos e",segundos_rest,"segundos.")

# %% [markdown]
# ## Exercício 4: OK
# Tendo como dado de entrada a altura (h) e o sexo de uma pessoa, construa um algoritmo que calcule
# seu peso (Massa: Quilogramas) ideal, utilizando as seguintes fórmulas:
#
# ✓ Para homens: (72.7 ∗ ℎ) − 58
#
# ✓ Para mulheres: (62.1 ∗ ℎ) − 44.7

# %%
H= float(input('Insira sua altura em metros: '))   
S= bool(input('Digite 0 para mulher ou 1 para homem: '))

if (S):
  peso_ideal=(72.7*H)-58
else:
  peso_ideal=(62.1*H)-44.7

#peso_ideal= S*((72.7*H)-58)+ (not(S))*((62.1*H)-44.7)

#peso_ideal=((72.7*H)-58) if S else ((62.1*H)-44.7)

print(f'Seu peso ideal é de {peso_ideal} quilogramas')
# Out:
# altura em metros: 1.85
# qual teu sexo? Digite 0 para mulher ou digite 1 para homem. 1
# Seu peso ideal é de 76.495 quilogramas

# %% [markdown]
# ## Exercício 5: OK
# Escrever um algoritmo em Python que exiba o público total (inteiro) de um jogo de futebol e
# forneça a arrecadação (R$: real) do jogo, sabendo que:
#
# ![image.png](data:image/png;base64,...)

# %%
import sys

publico = 0
Arrecadação = 0.00


while publico < 2:                              # Aqui ficaria a quantidade limite de pessoas
    Idade = int(input("Qual a sua idade: "))
    Ingresso = float(input("Valor do ingresso: R$ "))

    if Idade < 10:
        Ingresso = 0.00
        print(f'R$ {Ingresso: 2f}\n Crianças abaixo de 10 anos não pagam \n')
        publico = publico + 1
        Arrecadação = Arrecadação + Ingresso

    elif Idade > 10 and Idade < 18:
        Ingresso = Ingresso / 2
        print(f'R$ {Ingresso: .2f}\n Jovens de 11 a 17 pagam ½ entrada \n')
        publico = publico + 1
        Arrecadação = Arrecadação + Ingresso

    else:
        alimento = int(input("\nTrouxe alimento?\n 1 - Sim\n 2 - não: \n ->"))
        if alimento == 1:
            Ingresso = Ingresso / 2
            publico = publico + 1
            Arrecadação = Arrecadação + Ingresso
            print(f'Valor do ingresso: R$ {Ingresso: .2f}\n')

        else:
            print(f'Valor do ingresso: R$ {Ingresso: .2f}\n')
            publico = publico + 1
            Arrecadação = Arrecadação + Ingresso

print(f'Total de {publico} pessoas e R$ {Arrecadação: .2f} em ingressos vendidos')

# %% [markdown]
# ## Exercício 6: OK
# Faça um algoritmo que leia um número positivo e exiba se seu quadrado é ímpar e múltiplo de 11.

# %%
NP = 0
while not(NP > 0):
  NP = int(input('Insira um numero positivo: '))
  if (NP <= 0): 
    print('Valor inválido, digite novamente')

QuadNP = NP * NP
NPimp = QuadNP % 2

if (NPimp == 1):
  print('O numero eh impar')
else:
  print('O numero eh par')

Mult11 = QuadNP % 11

if (Mult11 == 0):
  print('O numero eh multiplo de 11 SIM')
else:
  print('O numero NAO eh multiplo de 11')
# Out:
# Insira um numero positivo: -2
# Valor inválido, digite novamente
# Insira um numero positivo: 56241
# O numero eh impar
# O numero NAO eh multiplo de 11

# %% [markdown]
# ## Exercício 7: OK
# Escrever um algoritmo em Python que leia o Preço de uma mercadoria e exiba o preço na tela
# reajustado de 3%. O usuário escolherá a Opção: “Acréscimo” ou “Desconto” para o reajuste de 3 %.
#
# a. Faça agora o mesmo exercício, entretanto; lendo o reajuste (em %) do usuário.

# %%
mercadoria = float(input("Insira o valor da mercadoria: "))
preco = mercadoria * 0.03
opcao = int(input("Gostaria de um acréscimo ou desconto? \n"
                  "1 - Desconto \n"
                  "2 - Acréscimo \n"
                  "-> "))
if (opcao == 1):
    Desconto = mercadoria - preco
    print(f'{Desconto: .2f}')
elif (opcao == 2):
    Acrescimo = mercadoria + preco
    print(f'{Acrescimo: .2f}')
else:
    print("Opção errada. Escolha novamente!")

# %% [markdown]
# ## Exercício 8: OK
# Escrever um algoritmo em Python que leia uma temperatura em Celsius (C) ou Fahrenheit (F) e faça
# a conversão entre as unidades. Considere que o usuário informe:
#
# ![image.png](data:image/png;base64,...)

# %%
Opcao = int(input("Qual a unidade que você deseja coverter? \n"
                  "1 - De Celsius para Fahrenheit\n"
                  "2 - De Fahrenheit para Celsius\n "
                  "-> "))

if (Opcao == 1):
    celsius = int(input("Insira o grau na unidade Celsius (C°): "))
    ctof = celsius * 1.8 + 32
    print(F'{ctof} Fahrenheit')
elif (Opcao == 2):
    Fahrenheit = int(input("Insira o grau na unidade Fahrenheit (F°): "))
    ftoc = (Fahrenheit - 32) / 1.8
    print(F'{ftoc} celsius')
else:
    print("Opção errada. Encerrando a aplicação...")

# %% [markdown]
# ## Execício 9: OK
# Escrever um algoritmo em Python que determine a conversão entre as moedas: Real, Dólar e Libra,
# de uma determinada quantidade em espécie e moeda informadas pelo usuário, sabendo que:
#
# ![image.png](data:image/png;base64,...)

# %%
MoedaC = 0

MoedaE = int(input('Selecione a moeda de entrada: 1 - Real / 2 - Dolar / 3 - Libra: '))
MoedaS = int(input('Selecione a moeda de saida: 1 - Real / 2 - Dolar / 3 - Libra: '))
Valor = float(input('Insira o valor para conersao: '))

if (MoedaE == 1 and MoedaS == 2):
  print(f'Valor inserido de R${Valor}')
  MoedaC = Valor * 0.19
  print(f'Valor final convertido de Real para Dolar foi de US${MoedaC}')
elif (MoedaE == 1 and MoedaS == 3):
  print(f'Valor inserido de R${Valor}')
  MoedaC = Valor * 0.15
  print(f'Valor final convertido de Real para Dolar foi de £${MoedaC}')
elif (MoedaE == 2 and MoedaS == 1):
  print(f'Valor inserido de US${Valor}')
  MoedaC = Valor * 5.32
  print(f'Valor final convertido de Real para Dolar foi de R${MoedaC}')
elif (MoedaE == 2 and MoedaS == 3):
  print(f'Valor inserido de US${Valor}')
  MoedaC = Valor * 0.78
  print(f'Valor final convertido de Real para Dolar foi de £${MoedaC}')
elif (MoedaE == 3 and MoedaS == 1):
  print(f'Valor inserido de £{Valor}')
  MoedaC = Valor * 6.8
  print(f'Valor final convertido de Real para Dolar foi de R${MoedaC}')
elif (MoedaE == 3 and MoedaS == 2):
  print(f'Valor inserido de £{Valor}')
  MoedaC = Valor * 1.28
  print(f'Valor final convertido de Real para Dolar foi de US${MoedaC}')
# Out:
# Selecione a moeda de entrada: 1 - Real / 2 - Dolar / 3 - Libra: 1
# Selecione a moeda de saida: 1 - Real / 2 - Dolar / 3 - Libra: 2
# Insira o valor para conersao: 10
# Valor inserido de R$10.0
# Valor final convertido de Real para Dolar foi de US$1.9

# %% [markdown]
# ## Exercício 10: OK
#
# Escrever a mesma lógica do exercício 9 para mudar a unidade da variável Massa para Onça (Oz),
# Toneladas e Quilograma. (Ver no Google a relação entre essas unidades de Massa)

# %%
MassaC = 0

MassaE = int(input('Selecione a unidade de massa de entrada: 1 - Onça / 2 - Toneladas / 3 - Quilograma: '))
MassaS = int(input('Selecione a unidade de massa de saida: 1 - Onça / 2 - Toneladas / 3 - Quilograma: '))
Massa = float(input('Insira a massa para conersao: '))

if (MassaE == 1 and MassaS == 2):
  print(f'O valor inserido foi de {Massa}Oz')
  MassaC = Massa * 2.835e-5
  print(f'Valor final convertido de Onças para Toneladas foi de aproximadamente {MassaC: .3f}t')
elif (MassaE == 1 and MassaS == 3):
  print(f'O valor inserido foi de {Massa}Oz')
  MassaC = Massa * 0.028
  print(f'Valor final convertido de Onças para Quilogramas foi de aproximadamente {MassaC: .3f}Kg')
elif (MassaE == 2 and MassaS == 1):
  print(f'O valor inserido foi de {Massa}t')
  MassaC = Massa * 35274
  print(f'Valor final convertido de Toneladas para Onças foi de aproximadamente {MassaC: .3f}Oz')
elif (MassaE == 2 and MassaS == 3):
  print(f'O valor inserido foi de {Massa}t')
  MassaC = Massa * 1000
  print(f'Valor final convertido de Toneladas para Kilogramas foi de aproximadamente {MassaC: .3f}Kg')
elif (MassaE == 3 and MassaS == 1):
  print(f'O valor inserido foi de {Massa}Kg')
  MassaC = Massa * 35.274
  print(f'Valor final convertido de Quilogramas para Onças foi de aproximadamente {MassaC: .3f}Oz')
elif (MassaE == 3 and MassaS == 2):
  print(f'O valor inserido foi de {Massa}Kg')
  MassaC = Massa * 0.001
  print(f'Valor final convertido de Quilogramas para Toneladas foi de aproximadamente {MassaC: .3f}t')
# Out:
# Selecione a unidade de massa de entrada: 1 - Onça / 2 - Toneladas / 3 - Quilograma: 1
# Selecione a unidade de massa de saida: 1 - Onça / 2 - Toneladas / 3 - Quilograma: 2
# Insira a massa para conersao: 40000
# O valor inserido foi de 40000.0Oz
# Valor final convertido de Onças para Toneladas foi de aproximadamente  1.134t

# %% [markdown]
# ## Exercício 11: OK
# Escrever um algoritmo que leia de apenas um (1) veículo de um estacionamento do shopping:
#
# ![image.png](data:image/png;base64,...)

# %%
hrentr = int(input('Hora de entrada: '))
minsentr = int(input('minss de entrada: '))
hrsaida= int(input('Hora de saida: '))
minsentr = int(input('minss de saida'))
preco = float(input('Valor pago a cada 30 minutos: '))

if (hrentr > hrsaida):
    print('Erro no horário de entrada e saída')

else:
        if(minsentr - minsentr <0):
            hora = hrsaida - hrentr - 1
            mins = minsentr - minsentr + 60
        else:
            mins = minsentr - minsentr
            hora = hrsaida - hrentr
            if(hora >= 24):
                print('Não é permitido passar mais de 24 horas no estacionamento')
            else:
                valor = ((hora * 2) * preco) + ((mins * preco)/30)
                if (valor <= 10):
                    print('carência gratuita de 30 minutos.')
                else:
                    print(f'Preço total a pagar: R$ {valor: .2f}')

        print(f'Permaneceu no estacionamento: {hora} hora(s) e {mins} minutos(s) ')
# Out:
# Hora de entrada: 14
# minss de entrada: 36
# Hora de saida: 15
# minss de saida23
# Valor pago a cada 30 minutos: 10
# Preço total a pagar: R$  20.00
# Permaneceu no estacionamento: 1 hora(s) e 0 minutos(s)

# %% [markdown]
# ## Exercício 12: OK
#  Escrever um algoritmo em Python que leia a Massa (Quilos) e a Altura (Metros) do indivíduo
# calculando o IMC = Massa / Altura2
#
# Após isso, classifique-o conforme a tabela:
#
# ![image.png](data:image/png;base64,...)

# %%
massa = float(input('Digite sua massa: '))
altura = float(input('Digite sua altura (em metros): '))
IMC = massa/pow(altura,2)

if (IMC<18.5):
  msg='Magreza'
elif (IMC>=18.5 and IMC<25):
  msg='Saudavel'
elif (IMC>=25 and IMC<30):
  msg='Sobrepeso'
elif (IMC>=30 and IMC<35):
  msg='Obesidade Grau I'
elif (IMC>=35 and IMC<40):
  msg='Obesidade Grau II (Severa)'
elif (IMC>=40):
  msg='Obesidade Grau III (mórbida)'
print(f'IMC: {IMC:.2f}, Classificação: {msg}')
# Out:
# Digite sua massa: 72
# Digite sua altura (em metros): 1.85
# IMC: 21.04, Classificação: Saudavel

# %% [markdown]
# ## Exercício 13: OK
#
# Escrever um algoritmo em C que leia três (3) números reais quaisquer e exiba o cubo da média deles
# se está média estiver fora do intervalo fechado [10𝞥, 200𝞥]. Caso contrário, exiba a própria média.
# Valor de 𝞥 (PHI = 11.52743: Use 5 casas decimais: ":5"

# %%
#include <stdio.h>

#include <math.h>

int main()
{
    int num1, num2, num3;

    printf("Digite o primeiro numero: ");
    scanf_s("%d", & num1);
    printf("Digite o segundo numero: ");
    scanf_s("%d", & num2);
    printf("Digite o terceiro numero: ");
    scanf_s("%d", & num3);
    int media = (num1 + num2 + num3) / 3;
    double cubo = pow(media, 3);
    double
    if ((media > 10) && (media < 200))
        printf (" O Cubo deste intervalo e %f\n", cubo);
    else
        printf (" A media deste intervalo e %d\n", media);
}

# %% [markdown]
# ## Exercício 14: OK
# Escrever um algoritmo que leia as notas entre [0, 10]: AV1, AV2 e PF e faltas: TF de um (1) aluno
# da UVV, sendo que:
#
# ![image.png](data:image/png;base64,...)
#
# E; exiba na tela seus Resultados: Parciais e Final (STATUS: Aprovado, Prova Final, Reprovado por Falta ou Reprovado).

# %%
N1 = int (input('coloque a nota 1: '))
N2 = int (input('coloque a nota 2: '))
FALTAS = int (input('coloque suas faltas: '))
M = (N1 + N2) / 2
print(f'Sua media: {M}')


if FALTAS >= 20:
  print('vc foi reprovado por falta: ')
elif M >= 7:
  print('vc passou: ')
elif M  < 3:
  print('reprovou: ')
elif M < 7 and M >= 3:
  print('vc foi pra recuperação: ')
  PF = int (input('nota da prova final: '))
  print(f'Sua nota final: {PF}')
  if (M + PF) / 2 >= 5:
    print('vc ta livre ')
  elif (M + PF) / 2 < 5:
    print('não deu irmão ')
# Out:
# coloque a nota 1: 5
# coloque a nota 2: 6
# coloque suas faltas: 2
# Sua media: 5.5
# vc foi pra recuperação:
# nota da prova final: 10
# Sua nota final: 10
# vc ta livre:

# %% [markdown]
# ## Exercício 15: OK
# Escrever um algoritmo que leia cinco (5) valores inteiros Positivos e distintos (teste e avise ao
# usuário se os valores informados forem iguais) e exiba na saída a média dos números PARES e a
# média dos números ÍMPARES lidos do usuário.

# %%
print('Digite números inteiros positivos e distintos: ')

N1 = int (input('Numero 1: '))
N2 = int (input('Numero 2: '))
N3 = int (input('Numero 3: '))
N4 = int (input('Numero 4: '))
N5 = int (input('Numero 5: '))

# numeros repetidos
if (N1 == N2):
  print('escreva valores diferentes {} {}: '.format(N1, N2))
elif (N1 == N3):
  print('escreva valores diferentes {} {}: '.format(N1, N3))
elif (N1 == N4):
  print('escreva valores diferentes {} {}: '.format(N1, N4))
elif (N1 == N5):
  print('escreva valores diferentes {} {}: '.format(N1, N5))
elif (N2 == N3):
  print('escreva valores diferentes {} {}: '.format(N2, N3))
elif (N2 == N4):
  print('escreva valores diferentes {} {}: '.format(N2, N4))
elif (N2 == N5):
  print('escreva valores diferentes {} {}: '.format(N2, N5))
elif (N3 == N4):
  print('escreva valores diferentes {} {}: '.format(N3, N4))
elif (N3 == N5):
  print('escreva valores diferentes {} {}: '.format(N3, N5))
elif (N4 == N5):
  print('escreva valores diferentes {} {}: '.format(N4, N5))
else:
 # DIFERENCIANDO PARES DOS IMPARES  
  if (N1 % 2 == 0):
    X = N1
    Y = (N2 + N3 + N4 + N5) / 4
    print('média dos numeros pares {} médis dos numeros impares {}: '.format(X, Y))
  elif (N1 % 2 == 0 and N2 % 2 == 0 ):
    X = (N1 + N2) / 2
    Y = (N3 + N4 + N5) / 3
    print('média dos numeros pares {} médis dos numeros impares {}: '.format(X, Y))
  elif (N1 % 2 == 0 and N2 % 2 == 0 and N3 % 2 == 0):
    X = (N1 + N2 + N3) / 3
    Y = (N4 + N5) / 2
    print('média dos numeros pares {} médis dos numeros impares {}: '.format(X, Y))
  elif (N1 % 2 == 0 and N2 % 2 == 0 and N3 % 2 == 0 and N4 % 2 == 0):
    X = (N1 + N2 + N3 + N4) / 4
    Y = N5
    print('média dos numeros pares {} médis dos numeros impares {}: '.format(X, Y))
  elif (N1 % 2 == 0 and N2 % 2 == 0 and N3 % 2 == 0 and N4 % 2 == 0 and N5 % 2 == 0):
    X = (N1 + N2 + N3 + N4 + N5) / 5
    Y = 0
    print('média dos numeros pares {} médis dos numeros impares {}: '.format(X, Y))
  elif (N2 % 2 == 0 ):
    X = N2
    Y = (N1 + N3 + N4 + N5) / 4
    print('média dos numeros pares {} médis dos numeros impares {}: '.format(X, Y))
  elif (N2 % 2 == 0 and N3 % 2 == 0 ):
    X = (N2 + N3) / 2
    Y = (N1 + N4 + N5) / 3
    print('média dos numeros pares {} médis dos numeros impares {}: '.format(X, Y))
  elif (N2 % 2 == 0 and N3 % 2 == 0 and N4 % 2 == 0):
    X = (N2 + N3 + N4) / 3
    Y = (N1 + N5) / 2
    print('média dos numeros pares {} médis dos numeros impares {}: '.format(X, Y))
  elif (N2 % 2 == 0 and N3 % 2 == 0 and N4 % 2 == 0 and N5 % 2 == 0):
    X = (N2 + N3 + N4 + N5) / 4
    Y = N1
    print('média dos numeros pares {} médis dos numeros impares {}: '.format(X, Y))
  elif (N3 % 2 == 0):
    X = N3
    Y = (N1 + N2 + N4 + N5) /4
    print('média dos numeros pares {} médis dos numeros impares {}: '.format(X, Y))
  elif (N3 % 2 == 0 and N4 % 2 == 0):
    X = (N3 + N4) / 2
    Y = (N1 + N2 + N5) / 3
    print('média dos numeros pares {} médis dos numeros impares {}: '.format(X, Y))
  elif (N3 % 2 == 0 and N4 % 2 == 0 and N5 % 2 == 0):
    X = (N3 + N4 + N5) / 3
    Y = (N1 + N2) / 2
    print('média dos numeros pares {} médis dos numeros impares {}: '.format(X, Y))
   elif (N4 % 2 == 0):
     X = N4
     Y = (N1 + N2 + N3 + N5) / 4
     print('média dos numeros pares {} médis dos numeros impares {}: '.format(X, Y))
    elif (N4 % 2 == 0 and N5 % 2 == 0):
      X = (N4 + N5) / 2
      Y = (N1 + N2 + N3) / 3
      print('média dos numeros pares {} médis dos numeros impares {}: '.format(X, Y))
    elif (N5 % 2 == 0):
      X = N5
      Y = (N1 + N2 + N3 + N4) / 4
      print('média dos numeros pares {} médis dos numeros impares {}: '.format(X, Y))
    elif (N1 % 2 == 1 and N2 % 2 == 1 and N3 % 2 == 1 and N4 % 2 == 1 and N5 % 2 == 1):
      X = 0
      Y = (N1 + N2 + N3 + N4 + N5) / 5
      print('média dos numeros pares {} médis dos numeros impares {}: '.format(X, Y))

# %% [markdown]
# ##Exercício 16: OK
# Escrever um algoritmo que leia três (3) valores reais quaisquer e distintos (teste e avise ao usuário
# se os valores informados forem iguais) e exiba na saída a média dos dois maiores números lidos.

# %%
print('Digite números inteiros positivos e distintos: ')

N1 = int (input('Numero 1: '))
N2 = int (input('Numero 2: '))
N3 = int (input('Numero 3: '))

if (N1 == N2):
  print('escreva valores diferentes {} {}: '.format(N1, N2))
elif (N1 == N3):
  print('escreva valores diferentes {} {}: '.format(N1, N3))
elif (N2 == N3):
  print('escreva valores diferentes {} {}: '.format(N2, N3))
else:
  if N1 > N3 and N2 > N3:
    X = (N1 + N2) / 2
    print('a soma dos 2 maiores numeros é {}: '.format(X))
  elif N1 > N2 and N3 > N2:
    X = (N1 + N3) / 2
    print('a soma dos 2 maiores numeros é {}: '.format(X))
  elif N2 > N1 and N3 > N1:
    X = (N2 + N3) / 2
    print('a soma dos 2 maiores numeros é {}: '.format(X))
# Out:
# Digite números inteiros positivos e distintos:
# Numero 1: 7
# Numero 2: 9
# Numero 3: 3
# a soma dos 2 maiores numeros é 8.0:

# %% [markdown]
# ## Exercício 17: OK
# Escrever um algoritmo que leia três (3) valores reais e positivos: 𝐴, 𝐵 𝑒 𝐶 e verifique se formam um
# triângulo. Além disso; se formarem um triângulo dizer qual tipo, a saber:
#
# ![image.png](data:image/png;base64,...)

# %%
A = float(input('Lado 1: '))
B = float(input('Lado 2: '))
C = float(input('Lado 3: '))
if A < B + C and B < A + C and C < A + B:
      print(f'As medidas {A}, {B} e {C} formam um triângulo:')
      if A == B and B == C:
            print('EQUILÁTERO')
      elif A != B and B != C and A != C:
            print('ESCALENO')
      else:
            print('ISOSCELES')
else:
    print(f'As medidas {A}, {B} e {C} NÃO formam um triângulo.')

# %% [markdown]
# # Referência Bibliográfica:

# %% [markdown]
# <div class="hint">
#         <b>APRENDA+ :</b><br/>
#         &#10139; Site oficial <b>Python</b>:
#         <a href="https://www.python.org/">Link</a><br/>
#         &#10139; Dica 1: Data Science: <b>Biblioteca Machine Learning: scikitlearn</b>:
#         <a href="https://scikit-learn.org/stable/">Link</a><br/>
#         &#10139; Dica 2: Data Science: <b>Biblioteca Plotagem Gráfica: matplotlib</b>:
#         <a href="https://matplotlib.org/3.1.1/index.html">Link</a><br/>
#         &#10139; Dica 3: Data Science: <b>Biblioteca Estrutura de Dados Tabular: pandas (dataframe)</b>:
#         <a href="https://pandas.pydata.org/pandas-docs/stable/index.html">Link</a><br/>
#         &#10139; Dica 4: Data Science: <b>Introdução à Biblioteca: pandas (dataframe)</b>:
#         <a href="https://colab.research.google.com/notebooks/mlcc/intro_to_pandas.ipynb">Link</a><br/>
#         &#10139; IDE JUPTER: <b>Pacote Anaconda (usar Python Offline)</b>:
#         <a href="https://anaconda.org">Link</a><br/>
#         &#10139; IDE PYTHON: <b>PyCharm (usar Python Offline)</b>:
#         <a href="https://www.jetbrains.com/pycharm/">Link</a><br/>
#     </div>

# %% [markdown]
# <div id="sfch3lqf5ezjg94l33h7zree5la8femztky"></div><script type="text/javascript" src="https://counter2.stat.ovh/private/counter.js?c=h3lqf5ezjg94l33h7zree5la8femztky&down=async" async></script><br><a href="https://www.webcontadores.com">contador de visitas para blog</a><noscript><a href="https://www.webcontadores.com" title="contador de visitas para blog"><img src="https://counter2.stat.ovh/private/webcontadores.php?c=h3lqf5ezjg94l33h7zree5la8femztky" border="0" title="contador de visitas para blog" alt="contador de visitas para blog"></a></noscript>

# %% [markdown]
# <a href="https://www.webcontadores.com" title="contador de visitas para blog"><img src="https://counter2.stat.ovh/private/webcontadores.php?c=h3lqf5ezjg94l33h7zree5la8femztky" border="0" title="contador de visitas para blog" alt="contador de visitas para blog"></a>
