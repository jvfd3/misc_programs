# %% [markdown]
# <?xml version="1.0" encoding="UTF-8"?>
# <html>
#   <body>
#     <header></header>
#         <CENTER>
#           <img src="https://www.uvv.br/wp-content/themes/uvvBr/templates/assets//img/logouvv.svg" alt="UVV-LOGO" style = width="100px"; height="100px">
#         </CENTER>
#         <CENTER><b>Laboratório de Programação- PYTHON</b><br/>
#         <CENTER><b>Lista de Exercício 2 - Estrutura de Repetição</b><br/>
#         <CENTER><b>Professor Alessandro Bertolani Oliveira</b></CENTER><br/>

# %% [markdown]
# # NOMES DO GRUPO:

# %% [markdown]
# ## Nome 1: Ícaro Leite Ramos

# %% [markdown]
# ## Nome 2:

# %% [markdown]
# ## Nome 3:

# %% [markdown]
# **FAZER 6 EXERCÍCIOS - NO MÍNIMO, SE FIZER MAIS ... MELHOR 😉 - A SUA ESCOLHA.**

# %% [markdown]
# ## Exercício 1:
# Escrever um algoritmo para exibir os múltiplos de 3 compreendidos no intervalo: [3 100].

# %%
print('Os multiplos de 3 no intervalo entre [3, 100] são: ')
i = 0
for contador in range (3, 101):
    if (contador % 3 == 0):
      i += 1
      print(f'{i}º Multiplo: {contador}')

# %% [markdown]
# ## Exercício 2:
# Escrever um algoritmo para exibir os múltiplos de 11, a soma e a média dos múltiplos de 11, em ordem
# decrescente (inversa), compreendidos entre o intervalo: [200 100]

# %%
quant=soma=0
i=200

print('Os múltiplos de 11 entre 200 e 100 são:')
for i in range (200,100,-1):
  if(i % 11 == 0):
   soma+=i
   quant+=1
   print(f'{quant}º múltiplo: {i}')
media=soma/quant
print(f'a media é {media} e a soma é {soma}')

# %% [markdown]
# ## Exercício 3:
# Escrever um algoritmo em Python para exibir os múltiplos de ƞ compreendidos entre o intervalo:
#
# ![image.png](data:image/png;base64,...)

# %%
LI = int(input('Insira o valor do limite inferior: '))
while (LI < 0):
  LI = int(input('Valor inválido, insira novamente o valor do limite inferior: '))

LS = int(input('Insira o valor do limite superior: '))
while (LS < LI):
  LS = int(input('Valor inválido, insira novamente o valor do limite superior: '))

n = int(input('Insira o valor de ƞ que seja maior ou igual a 2: '))
while (n < LI or n > LS):
  n = int(input('Valor inválido, insira novamente o valor de ƞ que seja maior ou igual a 2: '))

i = 0
for contador in range (LI, LS):
    if (contador % n == 0):
      i += 1
      print(f'{i}º Multiplo: {contador}')
# Out:
# Insira o valor do limite inferior: -1
# Valor inválido, insira novamente o valor do limite inferior: 2
# Insira o valor do limite superior: 1
# Valor inválido, insira novamente o valor do limite superior: 10
# Insira o valor de ƞ que seja maior ou igual a 2: 2
# 1º Multiplo: 2
# 2º Multiplo: 4
# 3º Multiplo: 6
# 4º Multiplo: 8

# %% [markdown]
# ## Exercício 4:
# Faça um algoritmo que exiba a soma dos PARES e ÍMPARES compreendidos entre [10 99].

# %%
par=impar=soma=0

for i in range(10,100):
  if (i % 2==0) :
    par+=i
  else:
    impar+=i
#  print(f'numero {i}:\tsoma atual dos pares é {par}\t e a soma atual dos ímpares é {impar}')
print(f'Soma final dos pares: {par}. Soma final dos ímpares: {impar}.')

# %% [markdown]
# ## Exercício 5:
# Escreva um algoritmo que leia de 10.000 habitantes de uma pequena cidade se está empregado ou não e
# exiba em porcentagem a quantidade de empregados e desempregados desta pequena cidade.

# %%
E = 0
D = 0
Hab = 4
for contador in range (0,Hab):
  Emp = int(input('Insira 1 para empregado e 0 para desempregado: '))
  while (Emp != 1 and Emp != 0):
    Emp = int(input('Valor INVALIDO. Insira 1 para empregado e 0 para desempregado: '))
  if (Emp == 1):
    E += 1
  else:
    D += 1

PE = (E / Hab) * 100
PD = (D / Hab) * 100
print(f'Porcentagem de empregados: {PE}%')
print(f'Porcentagem de desempregados: {PD}%')
# Out:
# Insira 1 para empregado e 0 para desempregado: 2
# Valor INVALIDO. Insira 1 para empregado e 0 para desempregado: 1
# Insira 1 para empregado e 0 para desempregado: 0
# Insira 1 para empregado e 0 para desempregado: 3
# Valor INVALIDO. Insira 1 para empregado e 0 para desempregado: 0
# Insira 1 para empregado e 0 para desempregado: 2
# Valor INVALIDO. Insira 1 para empregado e 0 para desempregado: 1
# Porcentagem de empregados: 50.0%
# Porcentagem de desempregados: 50.0%

# %% [markdown]
# ## Exercício 6:
# Escreva um algoritmo que leia o salário em reais (R$) de 1000 clientes de um shopping e exiba na tela,
# em porcentagem, a divisão dos clientes por tipo: A, B ou C, conforme a seguir:
#
# ![image.png](data:image/png;base64,...)

# %%
Clie = 1000
SM = 998.05
A = 0
B = 0
C = 0
for contador in range (0,Clie):
  Sal = float(input('Insira o salario em reais: '))
  if (Sal >= (SM*15)):
    A += 1
  elif (Sal < (SM*15) and Sal >= (SM*5)):
    B += 1
  elif (Sal < (SM*5)):
    C += 1

PA = (A / Clie) * 100
PB = (B / Clie) * 100
PC = (C / Clie) * 100
print(f'Porcentagem de clientes A: {PA: .1f}%')
print(f'Porcentagem de clientes B: {PB: .1f}%')
print(f'Porcentagem de clientes C: {PC: .1f}%')
# Out:
# Insira o salario em reais: 160
# Insira o salario em reais: 10
# Insira o salario em reais: 100
# Porcentagem de clientes A:  33.3%
# Porcentagem de clientes B:  33.3%
# Porcentagem de clientes C:  33.3%

# %% [markdown]
# ## Exercício 7:
# Escrever um algoritmo que conte e soma todos os números ímpares que são múltiplos de três e NÃO
# múltiplos de 5 que se encontram no intervalo [9 90]. Exiba a Contagem e a Soma destes números.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Exercício 8:
# Um marca de sucos que saber a opinião dos seus clientes sobre três diferentes novos “mix” de sabores.
# As degustações e votação se realizaram num supermercado durante certo período. Faça um algoritmo em
# C, que exiba a porcentagem dos clientes que gostaram da opção: 1: Mix 1, 2: Mix 2 ou 3: Mix 3 de
# sabores. Pare o algoritmo quando for digitada a opção zero (0).

# %% [markdown]
# ## Exercício 9:
# Escrever um algoritmo que leia vários Números 𝑁 (𝑢𝑚 𝑝𝑜𝑟 𝑣𝑒𝑧) que, no intervalo entre [10 90],
# divididos por 5 possuem resto 2. Exiba a soma dos números lidos, parando o programa para 𝑁 = 0.

# %% [markdown]
# ## Exercício 10:
# Escrever um algoritmo para que calcule a média dos números múltiplos de 6 que se encontram no
# intervalo de [6, 6𝑥]. Onde 𝑥 é um (1) único número inteiro positivo (𝑥 ≥ 1), lido do usuário

# %% [markdown]
# ## Exercício 11:
# Escrever um algoritmo em que o usuário entre com um número inteiro qualquer {ƞ ∈ ℤ} e exiba na tela
# os 50 números subseqüentes ao que foi digitado pelo usuário.

# %% [markdown]
# ## Exercício 12:
# Os comerciantes das Praias de Vila-Velha querem saber a temperatura média do verão capixaba. Escreva
# um algoritmo em C que leia a temperatura diária no verão e exiba a temperatura média da estação
# parando o algoritmo quando for digitada uma temperatura fora da estação. Sabe-se que as temperaturas,
# na estação de verão Capixaba, ficam acima de 28 °C.

# %% [markdown]
# # Referência Bibliográfica:

# %% [markdown]
# <div class="hint">
#         <b>APRENDA+ :</b><br/>
#         &#10139; Site oficial <b>Python</b>:
#         <a href="https://www.python.org/">Link</a><br/>
#         &#10139; Dica 1: Data Science: <b>Biblioteca Machine Learning: scikitlearn</b>:
#         <a href="https://scikit-learn.org/stable/">Link</a><br/>
#         &#10139; Dica 2: Data Science: <b>Biblioteca Plotagem Gráfica: matplotlib</b>:
#         <a href="https://matplotlib.org/3.1.1/index.html">Link</a><br/>
#         &#10139; Dica 3: Data Science: <b>Biblioteca Estrutura de Dados Tabular: pandas (dataframe)</b>:
#         <a href="https://pandas.pydata.org/pandas-docs/stable/index.html">Link</a><br/>
#         &#10139; Dica 4: Data Science: <b>Introdução à Biblioteca: pandas (dataframe)</b>:
#         <a href="https://colab.research.google.com/notebooks/mlcc/intro_to_pandas.ipynb">Link</a><br/>
#         &#10139; IDE JUPTER: <b>Pacote Anaconda (usar Python Offline)</b>:
#         <a href="https://anaconda.org">Link</a><br/>
#         &#10139; IDE PYTHON: <b>PyCharm (usar Python Offline)</b>:
#         <a href="https://www.jetbrains.com/pycharm/">Link</a><br/>
#     </div>

# %% [markdown]
# <div id="sfch3lqf5ezjg94l33h7zree5la8femztky"></div><script type="text/javascript" src="https://counter2.stat.ovh/private/counter.js?c=h3lqf5ezjg94l33h7zree5la8femztky&down=async" async></script><br><a href="https://www.webcontadores.com">contador de visitas para blog</a><noscript><a href="https://www.webcontadores.com" title="contador de visitas para blog"><img src="https://counter2.stat.ovh/private/webcontadores.php?c=h3lqf5ezjg94l33h7zree5la8femztky" border="0" title="contador de visitas para blog" alt="contador de visitas para blog"></a></noscript>

# %% [markdown]
# <a href="https://www.webcontadores.com" title="contador de visitas para blog"><img src="https://counter2.stat.ovh/private/webcontadores.php?c=h3lqf5ezjg94l33h7zree5la8femztky" border="0" title="contador de visitas para blog" alt="contador de visitas para blog"></a>
